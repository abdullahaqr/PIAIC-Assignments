# %%
import numpy as np
from PIL import Image
# Import the os module, for the os.walk function
import os
# Set the directory you want to start from
rootDir = 'numpy-photos'
arr = np.zeros([20, 200, 200])
for dirName, subdirList, fileList in os.walk(rootDir):
    print('Found directory: %s' % dirName)
    for fname in fileList:
        print('\t%s' % fname)
        filepath = dirName+os.sep+fname
        if filepath.endswith('.jpg'):
            print("resized photoes")
            img = Image.open(filepath)
            img = img.resize((200,200))
            print(img)
            arr = img
            print("3-dimentional array :")
            print(arr)
# Out:
# Found directory: numpy-photos
# 	1.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x184368759B0>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x184368759B0>
# 	10.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 	11.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
# 	12.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F54940>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F54940>
# 	13.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F542B0>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F542B0>
# 	14.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F54940>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F54940>
# 	15.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
# 	16.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F543C8>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F543C8>
# 	17.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
# 	18.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F54940>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F54940>
# 	19.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 	2.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18436875EB8>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18436875EB8>
# 	20.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F47710>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F47710>
# 	3.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F475F8>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F475F8>
# 	4.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 	5.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F47668>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F47668>
# 	6.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F4F780>
# 	7.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F56438>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F56438>
# 	8.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F69CF8>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F69CF8>
# 	9.jpg
# resized photoes
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
# 3-dimentional array :
# <PIL.Image.Image image mode=RGB size=200x200 at 0x18437F545C0>
